# %% [markdown]
# <a href="https://colab.research.google.com/github/Simeen01/Pandas/blob/main/Pandas_read_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pd.read_csv("//Users//simeenkhan//Downloads//Datasets//Movieratingdata.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-71499e1a419c> in <module>()
# ----> 1 pd.read_csv("//Users//simeenkhan//Downloads//Datasets//Movieratingdata.csv")
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df = pd.read_csv("/content/drive/MyDrive/Datasets/Movieratingdata.csv",nrows=15, usecols=[2,5])
df
# Out:
#                  MOVIE_TITLE  RATING
# 0                      Riot      8.0
# 1           The Protector 2      5.0
# 2             Batman Begins      9.0
# 3   In the Heart of the Sea      5.0
# 4                    Adrift      4.0
# 5                    Adrift      5.0
# 6                   Everest      6.0
# 7               Rescue Dawn      8.0
# 8              The Revenant     10.0
# 9              The Revenant      9.0
# 10             The Revenant      9.2
# 11             The Revenant      6.0
# 12             The Revenant      9.0
# 13             The Revenant      8.0
# 14             The Revenant      7.0

# %%
df.head()
# Out:
#    USER_ID  MOVIE_ID               MOVIE_TITLE  PRODUCTION_YEAR  \
# 0        1   4642044                     Riot              2015
# 1        2   1925518          The Protector 2              2013
# 2        3    372784            Batman Begins              2005
# 3        4   1390411  In the Heart of the Sea              2015
# 4        5   6306064                   Adrift              2018
#
#                                               GENRES  RATING
# 0                                             Action     8.0
# 1                                             Action     5.0
# 2                                   Action|Adventure     9.0
# 3  Action|Adventure|Biography|Drama|History|Thriller     5.0
# 4  Action|Adventure|Biography|Drama|Romance|Thriller     4.0

# %%
df.tail(4)
# Out:
#      USER_ID  MOVIE_ID          MOVIE_TITLE  PRODUCTION_YEAR           GENRES  \
# 496      497   4196776        Jason Bourne              2016  Action|Thriller
# 497      498   7456310                Anna              2019  Action|Thriller
# 498      499   8106534       6 Underground              2019  Action|Thriller
# 499      500   2302755  Olympus Has Fallen              2013  Action|Thriller
#
#      RATING
# 496     6.0
# 497     7.0
# 498     4.0
# 499     1.0

# %%
#skiprows=1 - that row gets removed
#skiprows = [1] - row in index 1 gets removed
df = pd.read_csv("/content/drive/MyDrive/Datasets/Movieratingdata.csv",skiprows=[1])
df
# Out:
#      USER_ID  MOVIE_ID               MOVIE_TITLE  PRODUCTION_YEAR  \
# 0          2   1925518          The Protector 2              2013
# 1          3    372784            Batman Begins              2005
# 2          4   1390411  In the Heart of the Sea              2015
# 3          5   6306064                   Adrift              2018
# 4          6   6306064                   Adrift              2018
# ..       ...       ...                       ...              ...
# 494      496   1846589            Hunter Killer              2018
# 495      497   4196776             Jason Bourne              2016
# 496      498   7456310                     Anna              2019
# 497      499   8106534            6 Underground              2019
# 498      500   2302755       Olympus Has Fallen              2013
#
#                                                 GENRES  RATING
# 0                                               Action     5.0
# ...

# %%
df = pd.read_csv("/content/drive/MyDrive/Datasets/Movieratingdata.csv",index_col=1)
df
# Out:
#           USER_ID               MOVIE_TITLE  PRODUCTION_YEAR  \
# MOVIE_ID
# 4642044         1                     Riot              2015
# 1925518         2          The Protector 2              2013
# 372784          3            Batman Begins              2005
# 1390411         4  In the Heart of the Sea              2015
# 6306064         5                   Adrift              2018
# ...           ...                       ...              ...
# 1846589       496            Hunter Killer              2018
# 4196776       497             Jason Bourne              2016
# 7456310       498                     Anna              2019
# 8106534       499            6 Underground              2019
# 2302755       500       Olympus Has Fallen              2013
#
#                                                      GENRES  RATING
# MOVIE_ID
# 4642044                                              Action     8.0
# 1925518                                              Action     5.0
# ...

# %%
df = pd.read_csv("/content/drive/MyDrive/Datasets/Movieratingdata.csv",header=1)
df
# Out:
#        1  4642044                     Riot   2015  \
# 0      2  1925518          The Protector 2   2013
# 1      3   372784            Batman Begins   2005
# 2      4  1390411  In the Heart of the Sea   2015
# 3      5  6306064                   Adrift   2018
# 4      6  6306064                   Adrift   2018
# ..   ...      ...                       ...   ...
# 494  496  1846589            Hunter Killer   2018
# 495  497  4196776             Jason Bourne   2016
# 496  498  7456310                     Anna   2019
# 497  499  8106534            6 Underground   2019
# 498  500  2302755       Olympus Has Fallen   2013
#
#                                                 Action    8
# 0                                               Action  5.0
# 1                                     Action|Adventure  9.0
# 2    Action|Adventure|Biography|Drama|History|Thriller  5.0
# 3    Action|Adventure|Biography|Drama|Romance|Thriller  4.0
# ...

# %%
#prefix works with header=None
df = pd.read_csv("/content/drive/MyDrive/Datasets/Movieratingdata.csv",header=None, prefix="Column")
df
# Out:
#      Column0   Column1                   Column2          Column3  \
# 0    USER_ID  MOVIE_ID               MOVIE_TITLE  PRODUCTION_YEAR
# 1          1   4642044                     Riot              2015
# 2          2   1925518          The Protector 2              2013
# 3          3    372784            Batman Begins              2005
# 4          4   1390411  In the Heart of the Sea              2015
# ..       ...       ...                       ...              ...
# 496      496   1846589            Hunter Killer              2018
# 497      497   4196776             Jason Bourne              2016
# 498      498   7456310                     Anna              2019
# 499      499   8106534            6 Underground              2019
# 500      500   2302755       Olympus Has Fallen              2013
#
#                                                Column4 Column5
# 0                                               GENRES  RATING
# ...

# %%
path = "/content/drive/MyDrive/Datasets/Movieratingdata.csv"

# %%
df = pd.read_csv(path,names=["a","b","c"])
df
# Out:
#                                                          a  \
# USER_ID MOVIE_ID MOVIE_TITLE               PRODUCTION_YEAR
# 1       4642044  Riot                                 2015
# 2       1925518  The Protector 2                      2013
# 3       372784   Batman Begins                        2005
# 4       1390411  In the Heart of the Sea              2015
# ...                                                    ...
# 496     1846589  Hunter Killer                        2018
# 497     4196776  Jason Bourne                         2016
# 498     7456310  Anna                                 2019
# 499     8106534  6 Underground                        2019
# 500     2302755  Olympus Has Fallen                   2013
#
#                                                                                            b  \
# USER_ID MOVIE_ID MOVIE_TITLE                                                          GENRES
# ...

# %%
df = pd.read_csv(path)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   USER_ID          500 non-null    int64
#  1   MOVIE_ID         500 non-null    int64
#  2   MOVIE_TITLE      500 non-null    object
#  3   PRODUCTION_YEAR  500 non-null    int64
#  4   GENRES           500 non-null    object
#  5   RATING           500 non-null    float64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 23.6+ KB

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df = pd.read_csv(path,usecols=[2,5])
type(pd.read_csv)
# Out:
# function

# %%
df.describe()
# Out:
#            RATING
# count  500.000000
# mean     7.046400
# std      1.584471
# min      1.000000
# 25%      6.000000
# 50%      7.000000
# 75%      8.000000
# max     10.000000

# %%
df.shape
# Out:
# (500, 2)
